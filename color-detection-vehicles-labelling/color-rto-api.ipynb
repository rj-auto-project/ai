# %%
import requests
import json

# URL and headers for the request
url = "https://www.carinfo.app/_next/data/sSW26uJkvQ8zEAJ20hUCE/rc-details/RJ11CA9921.json?rc=RJ11CA9921"

headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.9",
    "Cache-Control": "max-age=0",
    "Cookie": "_gcl_au=1.1.630235237.1717566722; _ga=GA1.1.326151587.1717566722; cto_bundle=; deviceId=948017; city=Delhi; cityId=10084; _clck=g8ldoc%7C2%7Cfmx%7C0%7C1617; session-token=eyJhbGciOiJkaXIiLCJlbmMiOiJBMjU2R0NNIn0..15wKwvo6Y39TRL3T.UvH5537DYQce2aqqFtsP9Eixi4W8F1XM0iaXoJYPhS-haNy_vA03ujI9Tz42wi3tDenc7pqX-3KyKiHYMIoNxBjc21ljRb6F_XCLmkg_-g4XAlcQiASv-wFmkGMP1iZvDyc-2B4HKjOX5e7EnPOKmlBgEMCzGSwE9in_GUlWL_z7S7utIT8h3JMVkoqOk1JO5GhnIy06SJuXv6QPpxWEw34mO5UeFZ0Hii6kBG8liR-A7feJNX1I4q0J87tgTdkllbqfTrscrslKlWZ46uhpmPdEnVg6gI3nov3LQLUCbuPZKzGUPfvCthNESkKAoR1Yz1mBVs-B0da0nKhEkUAzUZz4B33JSDj7LT6NQ2XgsLi_LrKLGqDu6p6AXb1zF85m8VL6VfE-n5H7A7uEkpaHMg5hgpH5kZ4U_ZH3iOaJdUWc62kjW9YUT3Q.NyqKKnebwPxBmVMsvtEt2A; _clsk=1b7nr7b%7C1719298792170%7C10%7C1%7Cv.clarity.ms%2Fcollect; _ga_MTH4BJD08V=GS1.1.1719297948.2.1.1719298792.0.0.0",
    "Sec-Ch-Ua": "\"Google Chrome\";v=\"125\", \"Chromium\";v=\"125\", \"Not.A/Brand\";v=\"24\"",
    "Sec-Ch-Ua-Mobile": "?1",
    "Sec-Ch-Ua-Platform": "\"Android\"",
    "Sec-Fetch-Dest": "document",
    "Sec-Fetch-Mode": "navigate",
    "Sec-Fetch-Site": "none",
    "Sec-Fetch-User": "?1",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Mobile Safari/537.36"
}

# Make the GET request
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Decode the JSON response
    data = response.json()
    print(json.dumps(data, indent=2))
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\toufiqhussain\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\toufiqhussain\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# ...
